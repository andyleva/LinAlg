# %% [markdown]
# ## Домашняя работа №1
# ### Часть 1 Линейное пространство. Основные понятия.

# %% [markdown]
# 1. Исследовать на линейную зависимость:
#
# $$𝑓1(𝑥)=𝑒^𝑥,𝑓2(𝑥)=1,𝑓3(𝑥)=𝑥+1,𝑓4(𝑥)=𝑥−𝑒^𝑥.$$

# %% [markdown]
# проанализировав  видим, что:
# $$f4(x) = f3(x) - f2(x) - f1(x)$$
# $$x-e^x = x + 1 -1 - e^x$$
# $$x-e^x = x - e^x$$
# векторы линейнозависимы, т.к. вектор f4(x) является комбинации трех остальных

# %% [markdown]
# 2. Исследовать на линейную зависимость:
# $$𝑓1(𝑥)=2,$$
# $$𝑓2(𝑥)=𝑥,$$
# $$𝑓3(𝑥)=𝑥^2,$$
# $$𝑓4(𝑥)=(𝑥+1)^2 $$

# %% [markdown]
# проанализировав видим, что:
# $$f1(x) + 4*f(x) + 2*f3(x) = 2*f4(x)$$
# $$2 + 4*x + 2*x^2 = 2*x^2 + 4*x + 2$$
# векторы линейнозависимы, т.к. вектор f4(x) является комбинации трех остальных

# %% [markdown]
# 3. Найти координаты вектора  𝑥=(2,3,5)∈ℝ3  в базисе  𝑏1=(0,0,10) ,  𝑏2=(2,0,0) ,  𝑏3=(0,1,0) .

# %% [markdown]
# $$x1*b1 + x2*b2 + x3*b3 = x$$
# $$x1(0,0,10) + x2(2,0,0) + x3(0,1,0) = (2,3,5)$$
# система уравнений
# $$0*x1 + 2*x2 + 0*x3 = 2$$
# $$0*x1 + 0*x2 + 1*x3 = 3$$
# $$10*x1 + 0*x2 + 0*x3 = 5$$
# $$x3 = 3, x1 = 1/2, x2 = 1$$
# итак ответ (1/2, 1, 5)

# %% [markdown]
# ##4. Найти координаты вектора  3𝑥2−2𝑥+2 ∈ ℝ3[𝑥] :
#
# а) в базисе  1 ,  𝑥 ,  𝑥2 ;
#
# б) в базисе  𝑥2 ,  𝑥−1 ,  1 .

# %% [markdown]
# a) координаты вектора (3,-2,2) в базисе (0,0,1)(0,1,0)(1,0,0)
# $$а(0,0,1)+b(0,1,0)+c(1,0,0)=(3,-2,2)$$
# $$0a+0b+1c=3 => c=3$$
# $$a0+1b+0c=-2 => b=-2$$
# $$1a+0b+0c=2 => a=2$$
# итак ответ (2,-2,3)

# %% [markdown]
# б) координаты вектора (3,-2,2) в базисе (1,0,0)(0,1,-1)(0,0,1)
# $$а(1,0,0)+b(0,1,-1)+c(0,0,1)=(3,-2,2)$$
# $$1a+0b+0c=3 => a=3$$
# $$0a+1b+0c=-2 => b=-2$$
# $$0a-1b+1c= 2 => -1*-2+1c=2 =>2+1c=2 => c=0$$
# итак ответ (3,-2,0)

# %% [markdown]
# ##5. Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, являющиеся линейными комбинациями данных векторов  {𝑢1,𝑢2,…,𝑢𝑛} .

# %% [markdown]
# рассмотрим: (0,a,b) => (0,a,b)+(0,c,d) = (0,a+c,b+d) => s(0,a,b) = (0,sa,sb)
# аналогично для случая (a,0,b) => явл линейным подпространством
# остсюда комбинация тоже явл подпространством

# %% [markdown]
# ### Часть 2 Линейное пространство. Основные понятия.

# %% [markdown]
# 1. Найти скалярное произведение векторов  𝑥,𝑦∈ℝ :
# $$а)  𝑥=(0,−3,6), 𝑦=(−4,7,9); $$
# $$б)  𝑥=(7,−4,0,1), 𝑦=(−3,1,11,2).$$

# %%
import numpy as np
# a)
a = np.array([0,-3,6])
b = np.array([-4,7,9])
print(f'Скалярное произведение а и b: {a.dot(b)}')
# Out:
# Скалярное произведение а и b: 33

# %%
# b)
a = np.array([7,-4,0,1])
b = np.array([-3,1,11,2])
print(f'Скалярное произведение а и b: {np.dot(a,b)}')
print(f'Скалярное произведение а и b: {a @ b}')
# Out:
# Скалярное произведение а и b: -23
# Скалярное произведение а и b: -23

# %% [markdown]
# 2. Найти нормы векторов  (4,2,4)  и  (12,3,4)  и угол между ними.

# %% [markdown]
# - $p = 1$ получаем $\ell_{1}$ норму (_манхэттенская норма_, или _манхэттенское расстояние_)
#
# $$\left\|x\right\|_{1} = \sum_{i}|x_{i}|;$$
#
# - $p = 2$ получаем $\ell_{2}$ норму (_евклидова норма_, наиболее часто используемая)
#
# $$\left\|x\right\|_{2} = \sqrt{\sum_{i}|x_{i}|^{2}}.$$

# %% [markdown]
# расчет угла между векторами
# $$cos\varphi = \frac{(x,y)}{\left \|x\right \|\cdot\left \|y\right \|}.$$

# %%
from numpy.linalg import norm
import math
a = np.array([4,2,4])
b = np.array([12,3,4])
print(f'манхэттенская норма вектора a: {norm(a, ord = 1)}')
print(f'манхэттенская норма вектора b: {norm(b, ord = 1)}')
print(f'евклидова норма вектора a: {norm(a, ord = 2)}')
print(f'евклидова норма вектора b: {norm(b, ord = 2)}')
cos_phi = np.dot(a,b) / norm(a) / norm(b)
print(f'угол между a и b: {math.degrees(cos_phi)} градусов')
# Out:
# манхэттенская норма вектора a: 10.0
# манхэттенская норма вектора b: 19.0
# евклидова норма вектора a: 6.0
# евклидова норма вектора b: 13.0
# угол между a и b: 51.419289306612335 градусов

# %% [markdown]
# 3. Будет ли линейное пространство евклидовым, если за скалярное произведение принять:
# а) произведение длин векторов;
# б) утроенное обычное скалярное произведение векторов?

# %%
а) нет, исходя из формулы скалярного произведения
в) да

# %% [markdown]
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# Базис e1,e2,…,en евклидова пространства называется ортонормированным, если его векторы попарно ортогональны и длина каждого из них равна единице:
# $$(ei,ej)= \begin{cases}
#     1,i=j,\\
#     0,i≠j\\
#      \end{cases}$$
#  $$, где  i = 1,2,…,n,  j = 1,2,…,n$$
#
# В ортонормированном базисе e1,e2,…,en длина вектора x вычисляется по формуле
# $$|x|=\sqrt{x1^2+x2^2+…+xn^2},$$
# где x1,…,xn — координаты вектора x

# %%
def len_vector(a,b,c):
    a1 = a**2
    len_a = math.sqrt(a1.sum())
    b1 = b**2
    len_b = math.sqrt(b1.sum())
    c1 = c**2
    len_c = math.sqrt(c1.sum())
    return len_a,len_b,len_c

# %%
print(f'длины векторов б): {len_vector(np.array([math.sqrt(1/2),-math.sqrt(1/2),0]), np.array([math.sqrt(1/2),math.sqrt(1/2),0]), np.array([0,0,1]))}')
print(f'длины векторов в): {len_vector(np.array([1/2,-1/2,0]),np.array([0,1/2,1/2]),np.array([0,0,1]))}')
print(f'длины векторов г): {len_vector(np.array([1,0,0]),np.array([0,1,0]),np.array([0,0,1]))}')
# Out:
# длины векторов б): (1.0, 1.0, 1.0)
# длины векторов в): (0.7071067811865476, 0.7071067811865476, 1.0)
# длины векторов г): (1.0, 1.0, 1.0)

# %% [markdown]
# Ответ: вариант б) и г) тк длины всех векторов ровны 1
